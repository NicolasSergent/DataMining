# %%
import pandas

# %%
series= pandas.Series([11,12,15,20,14,5,20,12,11,12,16,14,16], index = ["JO","Jena",'Jean',"Nico","Momo","Nana","Drew","Francis","bapt","aahha","ananan","popi","papa"])
print(series)
# Out:
# JO         11
# Jena       12
# Jean       15
# Nico       20
# Momo       14
# Nana        5
# Drew       20
# Francis    12
# bapt       11
# aahha      12
# ananan     16
# popi       14
# papa       16
# dtype: int64

# %%
series.describe()
# Out:
# count    13.000000
# mean     13.692308
# std       3.987159
# min       5.000000
# 25%      12.000000
# 50%      14.000000
# 75%      16.000000
# max      20.000000
# dtype: float64

# %%
import numpy as np

# %%
houses = np.genfromtxt("houses.csv", delimiter = ",", dtype= int)
houses
# Out:
# array([[212000,   4148,  25264],
#        [230000,   2501,  11891],
#        [339000,   4374,  25351],
#        [289000,   2398,  22215],
#        [160000,   2536,   9234],
#        [ 85000,   2368,  13329],
#        [ 85000,   1264,   8407],
#        [145000,   1572,  12588],
#        [164000,   2375,  16204],
#        [123500,   1161,   9626],
#        [180000,   1542,   8755],
#        [159500,   1464,  14636],
#        [156000,   2240,  21780],
#        [146500,   1269,  11250],
#        [101500,    924,   7361],
#        [109800,    768,  10497],
#        [182000,   1320,  15768],
#        [110000,   1845,  12153],
#        [125000,   1274,  13634],
#        [ 80000,   1905,  10890]])

# %%
dataframe=pandas.DataFrame(houses,columns=["Prix","Taille de la maison","Surface du terrain"])
dataframe
# Out:
#       Prix  Taille de la maison  Surface du terrain
# 0   212000                 4148               25264
# 1   230000                 2501               11891
# 2   339000                 4374               25351
# 3   289000                 2398               22215
# 4   160000                 2536                9234
# 5    85000                 2368               13329
# 6    85000                 1264                8407
# 7   145000                 1572               12588
# 8   164000                 2375               16204
# 9   123500                 1161                9626
# 10  180000                 1542                8755
# 11  159500                 1464               14636
# 12  156000                 2240               21780
# 13  146500                 1269               11250
# 14  101500                  924                7361
# 15  109800                  768               10497
# 16  182000                 1320               15768
# ...

# %%
groupe1=pandas.Series([11,12,15,20,14,5,20,12,11,12,16,14,16], index = ["JO","Jena",'Jean',"Nico","Momo","Nana","Drew","Francis","bapt","aahha","ananan","popi","papa"])

# %%
groupe1
# Out:
# JO         11
# Jena       12
# Jean       15
# Nico       20
# Momo       14
# Nana        5
# Drew       20
# Francis    12
# bapt       11
# aahha      12
# ananan     16
# popi       14
# papa       16
# dtype: int64

# %%
groupe2=pandas.Series([11,12,15,20,14,5,20,12,11,12,16,14,16], index = ["Jeane","Jo",'Jean',"Nico","Momo","Michel","Drew","Francis","Cloe",
                                                                        "aahha","ananan","popi","papa"])

# %%
dataframe=pandas.DataFrame({"Groupe 1" : groupe1,"Groupe 2": groupe2})
dataframe
# Out:
#          Groupe 1  Groupe 2
# Cloe          NaN      11.0
# Drew         20.0      20.0
# Francis      12.0      12.0
# JO           11.0       NaN
# Jean         15.0      15.0
# Jeane         NaN      11.0
# Jena         12.0       NaN
# Jo            NaN      12.0
# Michel        NaN       5.0
# Momo         14.0      14.0
# Nana          5.0       NaN
# Nico         20.0      20.0
# aahha        12.0      12.0
# ananan       16.0      16.0
# bapt         11.0       NaN
# papa         16.0      16.0
# popi         14.0      14.0

# %%
google_app= pandas.read_table("googleplaystore.csv",sep=",")
google_app
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
#pour lire un fichier csv fonction read.csv
google_app= pandas.read_csv("googleplaystore.csv")
google_app
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
#pour un ecrire un fichier lu sur son ordinateur en csv utiliser la methode to
google_app.to_csv("mon_dataframe.csv")

# %%
# pour setter un index la methode set_index
google_appIndex=google_app.set_index("App")

# %%
google_appIndex
# Out:
#                                                                Category  \
# App
# Photo Editor & Candy Camera & Grid & ScrapBook           ART_AND_DESIGN
# Coloring book moana                                      ART_AND_DESIGN
# U Launcher Lite – FREE Live Cool Themes, Hide Apps       ART_AND_DESIGN
# Sketch - Draw & Paint                                    ART_AND_DESIGN
# Pixel Draw - Number Art Coloring Book                    ART_AND_DESIGN
# ...                                                                 ...
# Sya9a Maroc - FR                                                 FAMILY
# Fr. Mike Schmitz Audio Teachings                                 FAMILY
# Parkinson Exercices FR                                          MEDICAL
# The SCP Foundation DB fr nn5n                       BOOKS_AND_REFERENCE
# iHoroscope - 2018 Daily Horoscope & Astrology                 LIFESTYLE
#
#                                                     Rating Reviews  \
# App
# ...

# %%
# pour acceder a un element de la dataframe deux methodes iloc(acceder grace aux index) et loc(acceder grace aux labels)
google_appIndex.iloc[4,3]
# Out:
# '2.8M'

# %%
google_appIndex.loc["Pixel Draw - Number Art Coloring Book","Size"]
# Out:
# '2.8M'

# %%
google_appIndex.loc["Udemy - Online Courses",:]
# Out:
#                          Category  Rating Reviews Size    Installs  Type  \
# App
# Udemy - Online Courses  EDUCATION     4.5   99020  18M  1,000,000+  Free
# Udemy - Online Courses  EDUCATION     4.5   99020  18M  1,000,000+  Free
# Udemy - Online Courses  EDUCATION     4.5   99020  18M  1,000,000+  Free
#
#                        Price Content Rating     Genres    Last Updated  \
# App
# Udemy - Online Courses     0       Everyone  Education  August 2, 2018
# Udemy - Online Courses     0       Everyone  Education  August 2, 2018
# Udemy - Online Courses     0       Everyone  Education  August 2, 2018
#
#                        Current Ver Android Ver
# App
# Udemy - Online Courses       5.0.4  5.0 and up
# Udemy - Online Courses       5.0.4  5.0 and up
# Udemy - Online Courses       5.0.4  5.0 and up

# %%
# Pour ajouter une colonne dans mon dataFrame 
category = google_appIndex["Category"]

# %%
google_appIndex["Categorie bis"]=category
google_appIndex.head()
# Out:
#                                                           Category  Rating  \
# App
# Photo Editor & Candy Camera & Grid & ScrapBook      ART_AND_DESIGN     4.1
# Coloring book moana                                 ART_AND_DESIGN     3.9
# U Launcher Lite – FREE Live Cool Themes, Hide Apps  ART_AND_DESIGN     4.7
# Sketch - Draw & Paint                               ART_AND_DESIGN     4.5
# Pixel Draw - Number Art Coloring Book               ART_AND_DESIGN     4.3
#
#                                                    Reviews  Size     Installs  \
# App
# Photo Editor & Candy Camera & Grid & ScrapBook         159   19M      10,000+
# Coloring book moana                                    967   14M     500,000+
# U Launcher Lite – FREE Live Cool Themes, Hide Apps   87510  8.7M   5,000,000+
# Sketch - Draw & Paint                               215644   25M  50,000,000+
# Pixel Draw - Number Art Coloring Book                  967  2.8M     100,000+
#
# ...

# %%
#poursupprimer des colonnes methode drop plus axis pour lui dire de travailler sur des colonnes
google_appIndex.drop(["Catageorie bis","Categorie bis","Android Ver"], axis = 1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-30-00dc1eb94bf9> in <module>
#       1 #poursupprimer des colonnes methode drop plus axis pour lui dire de travailler sur des colonnes
# ----> 2 google_appIndex.drop(["Catageorie bis","Categorie bis","Android Ver"], axis = 1)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4100             level=level,
#    4101             inplace=inplace,
# -> 4102             errors=errors,
#    4103         )
#    4104
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3912         for axis, labels in axes.items():
#    3913             if labels is not None:
# -> 3914                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3915
# ...

# %%
google_appIndex
# Out:
#                                                                Category  \
# App
# Photo Editor & Candy Camera & Grid & ScrapBook           ART_AND_DESIGN
# Coloring book moana                                      ART_AND_DESIGN
# U Launcher Lite – FREE Live Cool Themes, Hide Apps       ART_AND_DESIGN
# Sketch - Draw & Paint                                    ART_AND_DESIGN
# Pixel Draw - Number Art Coloring Book                    ART_AND_DESIGN
# ...                                                                 ...
# Sya9a Maroc - FR                                                 FAMILY
# Fr. Mike Schmitz Audio Teachings                                 FAMILY
# Parkinson Exercices FR                                          MEDICAL
# The SCP Foundation DB fr nn5n                       BOOKS_AND_REFERENCE
# iHoroscope - 2018 Daily Horoscope & Astrology                 LIFESTYLE
#
#                                                     Rating Reviews  \
# App
# ...

# %%
google_appIndex.drop(["Categorie bis","Android Ver"], axis = 1)
# Out:
#                                                                Category  \
# App
# Photo Editor & Candy Camera & Grid & ScrapBook           ART_AND_DESIGN
# Coloring book moana                                      ART_AND_DESIGN
# U Launcher Lite – FREE Live Cool Themes, Hide Apps       ART_AND_DESIGN
# Sketch - Draw & Paint                                    ART_AND_DESIGN
# Pixel Draw - Number Art Coloring Book                    ART_AND_DESIGN
# ...                                                                 ...
# Sya9a Maroc - FR                                                 FAMILY
# Fr. Mike Schmitz Audio Teachings                                 FAMILY
# Parkinson Exercices FR                                          MEDICAL
# The SCP Foundation DB fr nn5n                       BOOKS_AND_REFERENCE
# iHoroscope - 2018 Daily Horoscope & Astrology                 LIFESTYLE
#
#                                                     Rating Reviews  \
# App
# ...

# %%
#dataframe shape pour savoir le nbr lignes colonne d un tableau 
google_app.shape
# Out:
# (10841, 13)

# %%
#attribut pour savoir le nom  des colonnes du tableau 
google_app.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
#attribut pour gerer (savoir) les valeurs non repertorier et les calculer
google_app.isna().sum()
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       1
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          3
# dtype: int64

# %%
# pouur supprimer des valeur non referencer de mon dataframe dropna
google_app_sans_na = google_app.dropna()

# %%
google_app_sans_na.isna().sum()
# Out:
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size              0
# Installs          0
# Type              0
# Price             0
# Content Rating    0
# Genres            0
# Last Updated      0
# Current Ver       0
# Android Ver       0
# dtype: int64

# %%
# trier un tableau sort_values(by="")
google_app_sans_na.sort_values(by="Rating").head()
# Out:
#                                    App      Category  Rating Reviews  Size  \
# 625            House party - live chat        DATING     1.0       1  9.2M
# 6319  BJ Bridge Standard American 2018          GAME     1.0       1  4.9M
# 7926              Tech CU Card Manager       FINANCE     1.0       2  7.2M
# 7383                    Thistletown CI  PRODUCTIVITY     1.0       1  6.6M
# 5978     Truck Driving Test Class 3 BC        FAMILY     1.0       1  2.0M
#
#      Installs  Type  Price Content Rating        Genres    Last Updated  \
# 625       10+  Free      0     Mature 17+        Dating   July 31, 2018
# 6319   1,000+  Free      0       Everyone          Card    May 21, 2018
# 7926   1,000+  Free      0       Everyone       Finance   July 25, 2017
# 7383     100+  Free      0       Everyone  Productivity  March 15, 2018
# 5978      50+  Paid  $1.49       Everyone     Education   April 9, 2012
#
#      Current Ver   Android Ver
# 625         3.52  4.0.3 and up
# ...

# %%
#pour savoir le type de nos colonnes dans dataframe
google_app_sans_na.dtypes
# Out:
# App                object
# Category           object
# Rating            float64
# Reviews            object
# Size               object
# Installs           object
# Type               object
# Price              object
# Content Rating     object
# Genres             object
# Last Updated       object
# Current Ver        object
# Android Ver        object
# dtype: object

# %%
#pour decrire une colonne numerique
google_app_sans_na.describe()
# Out:
#             Rating
# count  9360.000000
# mean      4.191838
# std       0.515263
# min       1.000000
# 25%       4.000000
# 50%       4.300000
# 75%       4.500000
# max       5.000000

# %%
#pour decrire une colonne non numerique
google_app_sans_na.describe(include="all")
# Out:
#            App Category       Rating Reviews                Size    Installs  \
# count     9360     9360  9360.000000    9360                9360        9360
# unique    8190       33          NaN    5990                 413          19
# top     ROBLOX   FAMILY          NaN       2  Varies with device  1,000,000+
# freq         9     1746          NaN      83                1637        1576
# mean       NaN      NaN     4.191838     NaN                 NaN         NaN
# std        NaN      NaN     0.515263     NaN                 NaN         NaN
# min        NaN      NaN     1.000000     NaN                 NaN         NaN
# 25%        NaN      NaN     4.000000     NaN                 NaN         NaN
# 50%        NaN      NaN     4.300000     NaN                 NaN         NaN
# 75%        NaN      NaN     4.500000     NaN                 NaN         NaN
# max        NaN      NaN     5.000000     NaN                 NaN         NaN
#
# ...

# %%
#transformer des valeurs en numerique fonction apply() et pour creer une fonction temporaire lambda utilisable que cette fois ci
google_app_sans_na["Installs"]=google_app_sans_na["Installs"].apply(lambda x: x.replace("," , ""))
google_app_sans_na["Installs"]=google_app_sans_na["Installs"].apply(lambda x: x.replace("+" , ""))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-98-d9ae9a383713> in <module>
#       1 #transformer des valeurs en numerique fonction apply() et pour creer une fonction temporaire lambda utilisable que cette fois ci
# ----> 2 google_app_sans_na["Installs"]=google_app_sans_na["Installs"].apply(lambda x: x.replace("," , ""))
#       3 google_app_sans_na["Installs"]=google_app_sans_na["Installs"].apply(lambda x: x.replace("+" , ""))
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    4040             else:
#    4041                 values = self.astype(object).values
# -> 4042                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    4043
#    4044         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas\_libs\lib.pyx in pandas._libs.lib.map_infer()
#
# ...

# %%
google_app_sans_na.dtypes
# Out:
# App                object
# Category           object
# Rating            float64
# Reviews            object
# Size               object
# Installs            int64
# Type               object
# Price              object
# Content Rating     object
# Genres             object
# Last Updated       object
# Current Ver        object
# Android Ver        object
# dtype: object

# %%
google_app_sans_na["Installs"]=google_app_sans_na["Installs"].apply(lambda x: int(x))
# Out:
# C:\Users\nicolas\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
google_app_sans_na.dtypes
# Out:
# App                object
# Category           object
# Rating            float64
# Reviews            object
# Size               object
# Installs            int64
# Type               object
# Price              object
# Content Rating     object
# Genres             object
# Last Updated       object
# Current Ver        object
# Android Ver        object
# dtype: object

# %%
google_app_sans_na.describe()
# Out:
#             Rating      Installs
# count  9360.000000  9.360000e+03
# mean      4.191838  1.790875e+07
# std       0.515263  9.126637e+07
# min       1.000000  1.000000e+00
# 25%       4.000000  1.000000e+04
# 50%       4.300000  5.000000e+05
# 75%       4.500000  5.000000e+06
# max       5.000000  1.000000e+09

# %%
google_app_sans_na["Reviews"]=google_app_sans_na["Reviews"].apply(lambda x: int(x))
# Out:
# C:\Users\nicolas\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
google_app_sans_na.describe()
# Out:
#             Rating       Reviews      Installs
# count  9360.000000  9.360000e+03  9.360000e+03
# mean      4.191838  5.143767e+05  1.790875e+07
# std       0.515263  3.145023e+06  9.126637e+07
# min       1.000000  1.000000e+00  1.000000e+00
# 25%       4.000000  1.867500e+02  1.000000e+04
# 50%       4.300000  5.955000e+03  5.000000e+05
# 75%       4.500000  8.162750e+04  5.000000e+06
# max       5.000000  7.815831e+07  1.000000e+09

# %%
#faire des stats sur des valeurs qualitative value_counts pour compter
google_app_sans_na["Type"].value_counts()
# Out:
# Free    8715
# Paid     645
# Name: Type, dtype: int64

# %%
# pour filtrer un dataframe utiliser la fonction lock
google_app_sans_na.loc[google_app_sans_na["Rating"]>4.5,:]
# Out:
#                                                      App             Category  \
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 9                          Kids Paint Free - Drawing Fun       ART_AND_DESIGN
# 13                                 Mandala Coloring Book       ART_AND_DESIGN
# 16          Photo Designer - Write your name with shapes       ART_AND_DESIGN
# 19                                          ibis Paint X       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10810                                  Fr Lupupa Sermons             BUSINESS
# 10820                                    Fr. Daoud Lamei               FAMILY
# 10829                     Bulgarian French Dictionary Fr  BOOKS_AND_REFERENCE
# 10833                                        Chemin (fr)  BOOKS_AND_REFERENCE
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
#
# ...

# %%
google_app_sans_na.loc[(google_app_sans_na["Category"]== "BUSINESS") & (google_app_sans_na["Rating"]>4),:]
# Out:
#                                                      App  Category  Rating  \
# 187                         Visual Voicemail by MetroPCS  BUSINESS     4.1
# 188                                    Indeed Job Search  BUSINESS     4.3
# 189                                          Uber Driver  BUSINESS     4.4
# 190                                 ADP Mobile Solutions  BUSINESS     4.3
# 191                               Snag - Jobs Hiring Now  BUSINESS     4.3
# ...                                                  ...       ...     ...
# 10529                                 FK CLASSIC FOR YOU  BUSINESS     5.0
# 10659                                                 FN  BUSINESS     5.0
# 10706  Neon Blue Gaming Wallpaper&Theme fo Lenovo K8 ...  BUSINESS     4.6
# 10754                                     SCM FPS Status  BUSINESS     4.2
# 10810                                  Fr Lupupa Sermons  BUSINESS     4.8
#
# ...

# %%
#savoir les valeur uniques dune clonne unique
google_app_sans_na["Price"].unique()
# Out:
# array(['0', '$4.99', '$3.99', '$6.99', '$7.99', '$5.99', '$2.99', '$3.49',
#        '$1.99', '$9.99', '$7.49', '$0.99', '$9.00', '$5.49', '$10.00',
#        '$24.99', '$11.99', '$79.99', '$16.99', '$14.99', '$29.99',
#        '$12.99', '$2.49', '$10.99', '$1.50', '$19.99', '$15.99', '$33.99',
#        '$39.99', '$3.95', '$4.49', '$1.70', '$8.99', '$1.49', '$3.88',
#        '$399.99', '$17.99', '$400.00', '$3.02', '$1.76', '$4.84', '$4.77',
#        '$1.61', '$2.50', '$1.59', '$6.49', '$1.29', '$299.99', '$379.99',
#        '$37.99', '$18.99', '$389.99', '$8.49', '$1.75', '$14.00', '$2.00',
#        '$3.08', '$2.59', '$19.40', '$3.90', '$4.59', '$15.46', '$3.04',
#        '$13.99', '$4.29', '$3.28', '$4.60', '$1.00', '$2.95', '$2.90',
#        '$1.97', '$2.56', '$1.20'], dtype=object)

# %%
google_app_sans_na["Price"]=google_app_sans_na["Price"].apply(lambda x: x.replace("$" , ""))
google_app_sans_na["Price"]=google_app_sans_na["Price"].apply(lambda x: float(x))
# Out:
# C:\Users\nicolas\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\nicolas\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
google_app_sans_na["Price"].unique()
# Out:
# array([  0.  ,   4.99,   3.99,   6.99,   7.99,   5.99,   2.99,   3.49,
#          1.99,   9.99,   7.49,   0.99,   9.  ,   5.49,  10.  ,  24.99,
#         11.99,  79.99,  16.99,  14.99,  29.99,  12.99,   2.49,  10.99,
#          1.5 ,  19.99,  15.99,  33.99,  39.99,   3.95,   4.49,   1.7 ,
#          8.99,   1.49,   3.88, 399.99,  17.99, 400.  ,   3.02,   1.76,
#          4.84,   4.77,   1.61,   2.5 ,   1.59,   6.49,   1.29, 299.99,
#        379.99,  37.99,  18.99, 389.99,   8.49,   1.75,  14.  ,   2.  ,
#          3.08,   2.59,  19.4 ,   3.9 ,   4.59,  15.46,   3.04,  13.99,
#          4.29,   3.28,   4.6 ,   1.  ,   2.95,   2.9 ,   1.97,   2.56,
#          1.2 ])

# %%
# pour grouper des collonnes utiliser group by 
google_app_sans_na.groupby("Category").describe()
# Out:
#                      Rating                                                   \
#                       count      mean       std  min    25%  50%    75%  max
# Category
# ART_AND_DESIGN         61.0  4.377049  0.328326  3.4  4.100  4.4  4.700  5.0
# AUTO_AND_VEHICLES      73.0  4.190411  0.543692  2.1  4.000  4.3  4.600  4.9
# BEAUTY                 42.0  4.278571  0.362603  3.1  4.000  4.3  4.575  4.9
# BOOKS_AND_REFERENCE   178.0  4.346067  0.429046  2.7  4.100  4.5  4.600  5.0
# BUSINESS              303.0  4.121452  0.624422  1.0  3.900  4.3  4.500  5.0
# COMICS                 58.0  4.155172  0.537758  2.8  3.825  4.4  4.500  5.0
# COMMUNICATION         328.0  4.158537  0.426192  1.0  4.000  4.3  4.400  5.0
# DATING                195.0  3.970769  0.630510  1.0  3.700  4.1  4.400  5.0
# EDUCATION             155.0  4.389032  0.251894  3.5  4.200  4.4  4.600  4.9
# ENTERTAINMENT         149.0  4.126174  0.302556  3.0  3.900  4.2  4.300  4.7
# ...

# %%
# on peut grouper plusieur colonne 
google_app_sans_na.groupby(["Category","Genres"]).describe()
# Out:
#                                                         Rating            \
#                                                          count      mean
# Category          Genres
# ART_AND_DESIGN    Art & Design                            55.0  4.380000
#                   Art & Design;Creativity                  5.0  4.440000
#                   Art & Design;Pretend Play                1.0  3.900000
# AUTO_AND_VEHICLES Auto & Vehicles                         73.0  4.190411
# BEAUTY            Beauty                                  42.0  4.278571
# ...                                                        ...       ...
# TRAVEL_AND_LOCAL  Travel & Local;Action & Adventure        1.0  4.100000
# VIDEO_PLAYERS     Video Players & Editors                158.0  4.063924
#                   Video Players & Editors;Creativity       1.0  4.100000
#                   Video Players & Editors;Music & Video    1.0  4.000000
# ...
